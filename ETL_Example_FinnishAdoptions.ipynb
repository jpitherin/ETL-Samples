# %%
import pandas as pd
import datetime

# %%
##############
### Functions

def LoadOldCsv (filename):
    filepath = './Input_Data/' + filename
    LoadedCSV = pd.read_csv(filepath, sep=';', encoding='cp1250', skiprows = 2)
    
    return LoadedCSV


def EtlToCsv (dataframe, df_name, column_names):
    dataframe.to_csv(path_or_buf = './Output_Data/ETL_' + str(datetime.datetime.now().date()) + '_' + df_name + '.csv',
              header = column_names,
              index = False)

# %%
### Load datafile

df_old = LoadOldCsv(filename = 'FinlandAdoptions_2017.csv')

# %%
df_old.iloc[0:3,]
# Out:
#    Year         Country of birth  \
# 0  2017  COUNTRY OF BIRTH, TOTAL
# 1  2017                  Finland
# 2  2017   FOREIGN COUNTRY, TOTAL
#
#    Adoptions total Age groups, total Both sexes Adoptions, number  \
# 0                                                396
# 1                                                292
# 2                                                104
#
#    Adoptions total Age groups, total Males Adoptions, number  \
# 0                                                207
# 1                                                142
# 2                                                 65
#
#    Adoptions total Age groups, total Females Adoptions, number  \
# 0                                                189
# 1                                                150
# 2                                                 39
#
#    Adoptions total 0 - 17 Both sexes Adoptions, number  \
# 0                                                304
# 1                                                205
# 2                                                 99
#
#    Adoptions total 0 - 17 Males Adoptions, number  \
# 0                                             164
# 1                                             101
# 2                                              63
#
#    Adoptions total 0 - 17 Females Adoptions, number  \
# 0                                               140
# 1                                               104
# 2                                                36
#
#    Adoptions total 18 - Both sexes Adoptions, number  \
# 0                                                 92
# 1                                                 87
# 2                                                  5
#
#    Adoptions total 18 - Males Adoptions, number  \
# 0                                            43
# 1                                            41
# 2                                             2
#
#                             ...                            \
# 0                           ...
# 1                           ...
# 2                           ...
#
#    Two-parent adoptions 18 - Females Adoptions, number  \
# 0                                                  8
# 1                                                  8
# 2                                                  0
#
#    Single-parent adoptions Age groups, total Both sexes Adoptions, number  \
# 0                                                281
# 1                                                250
# 2                                                 31
#
#    Single-parent adoptions Age groups, total Males Adoptions, number  \
# 0                                                135
# 1                                                118
# 2                                                 17
#
#    Single-parent adoptions Age groups, total Females Adoptions, number  \
# 0                                                146
# 1                                                132
# 2                                                 14
#
#    Single-parent adoptions 0 - 17 Both sexes Adoptions, number  \
# 0                                                211
# 1                                                183
# 2                                                 28
#
#    Single-parent adoptions 0 - 17 Males Adoptions, number  \
# 0                                                106
# 1                                                 89
# 2                                                 17
#
#    Single-parent adoptions 0 - 17 Females Adoptions, number  \
# 0                                                105
# 1                                                 94
# 2                                                 11
#
#    Single-parent adoptions 18 - Both sexes Adoptions, number  \
# 0                                                 70
# 1                                                 67
# 2                                                  3
#
#    Single-parent adoptions 18 - Males Adoptions, number  \
# 0                                                 29
# 1                                                 29
# 2                                                  0
#
#    Single-parent adoptions 18 - Females Adoptions, number
# 0                                                 41
# 1                                                 38
# 2                                                  3
#
# [3 rows x 29 columns]

# %%
### transform csv file
# Create dataframes to put the transformed data into
columns_adoptions = ['Year','Country_of_Birth','Adoption_Type','Age_Group','Gender','Number']
Finland_Adoptions = pd.DataFrame(columns = columns_adoptions)

# length of each row
row_len = len(df_old.columns)

# length of each column
col_len = len(df_old)

# moving the data around

print(datetime.datetime.now())
for i in range(0,col_len): #col_len
    Year = df_old.iloc[i][0]
    Country_of_Birth = df_old.iloc[i][1]
    
    for j in range(2,row_len): #row_len
        column_name = df_old.columns[j].split()
        
        if(column_name[0] == 'Adoptions'):
            Adoption_Type = 'Total'
        elif(column_name[0] == 'Two-parent'):
            Adoption_Type = 'Two-parent'
        elif(column_name[0] == 'Single-parent'):
            Adoption_Type = 'Single-parent'
            
        
        if(column_name[2] == 'Age'):
            Age_Group = 'Total'
        elif(column_name[2] == '0'):
            Age_Group = '0-17'
        elif(column_name[2] == '18'):
            Age_Group = '18+'
        
        if((column_name[2] == '18') and (column_name[4] == 'Both')):
            Gender = 'Total'
        elif((column_name[2] == '18') and (column_name[4] == 'Males')):
            Gender = 'Male'
        elif((column_name[2] == '18') and (column_name[4] == 'Females')):
            Gender = 'Female'
            
        if((column_name[2] != '18') and (column_name[5] == 'Both')):
            Gender = 'Total'
        elif((column_name[2] != '18') and (column_name[5] == 'Males')):
            Gender = 'Male'
        elif((column_name[2] != '18') and (column_name[5] == 'Females')):
            Gender = 'Female'
        
        Number = df_old.iloc[i][j]
        
        # write this to a dataframe....
        df2 = pd.DataFrame(data = [[Year,Country_of_Birth,Adoption_Type,Age_Group,Gender,Number]], columns = columns_adoptions)
        Finland_Adoptions = Finland_Adoptions.append(df2)

print(datetime.datetime.now()) # 38 seconds
# Out:
# 2019-02-07 17:16:13.778684
# 2019-02-07 17:16:32.456375

# %%
#Finland_Adoptions

# %%
### Export to csv

EtlToCsv(dataframe = Finland_Adoptions, df_name = 'Finland_Adoptions', column_names = columns_adoptions)
